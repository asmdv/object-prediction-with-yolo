# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

with open('track_history.pkl', 'rb') as f:
    track_history = pickle.load(f)
# print(np.array(track_history[8])[:, 0])


plt.plot(np.array(track_history[8])[:, 0], np.array(track_history[8])[:, 1])

print(int(track_history[8][1][1]))

print(track_history[8])
# Out:
# 814
# ...
