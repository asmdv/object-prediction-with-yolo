# %%
from datasets import load_dataset

dataset = load_dataset("shawshankvkt/Walking_Tours")
# Out:
# ...
# Generating train split:   0%|          | 0/3 [00:00<?, ? examples/s]

# %%
dataset["train"]['image'][1]
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=400x225>
